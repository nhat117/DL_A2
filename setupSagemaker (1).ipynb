# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("2QmjAYvRQyX6M75pNuXYWXsPyd7_2xL6T9KhUw8zN6KGE3oiK")

# %%
from pyngrok import ngrok

# Get a list of all active tunnels
tunnels = ngrok.get_tunnels()

# Loop through and disconnect each tunnel
for tunnel in tunnels:
    print(f"Closing tunnel: {tunnel.public_url}")
    ngrok.disconnect(tunnel.public_url)

# Optional: Kill the ngrok process completely
ngrok.kill()

# %%
ssh_tunnel = ngrok.connect(8080, "http")
print("SSH tunnel:", ssh_tunnel.public_url)
# Out:
# SSH tunnel: https://18df17c0a74d.ngrok-free.app
# t=2025-10-08T23:38:39+0000 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=c5583c13c37c clientid=ceeebc2e6d8c567ce2294ef66a62c62c
# t=2025-10-08T23:53:02+0000 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=05d084059a09 err="write tcp 172.16.93.188:46980->3.136.132.147:443: write: broken pipe"

# %%
# %%bash
# touch ~/.ssh/authorized_keys
# chmod 600 ~/.ssh/authorized_keys
# echo "ssh-rsa ... nhatbuiminh@Nhats-MacBook-Pro.local" > ~/.ssh/authorized_keys

# %%
# !jupyter server list
# Out:
# Currently running servers:
# https://ip-172-16-34-81.ap-southeast-2.compute.internal:8443/ :: /home/ec2-user/SageMaker

# %%
# %%bash
# pip install cursor-notebook-mcp
# pip install "pydantic<2.11"
# Out:
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━��━━━━━━━━━ 0.0/2.1 MB ? eta -:--:--━━━━━━━━━━━ 2.1/2.1 MB 81.0 MB/s  0:00:00
# ...
#   Attempting uninstall: typing-inspection
#     Found existing installation: typing-inspection 0.4.1
#     Uninstalling typing-inspection-0.4.1:
#       Successfully uninstalled typing-inspection-0.4.1
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: pydanticm╺━━━━━━━━━━━━━━━━━━━━━━━  4/22 [pydantic-core]━━━━━━━━━━━━━━━━━  7/22 [httpcore]━━━━━━━━━━━━━━━━━  9/22 [dnspython]
#     Found existing installation: pydantic 2.9.2━━━━━━━━━━━━━━━  9/22 [dnspython]
# ...

# %%
# %%bash
# nohup cursor-notebook-mcp --transport streamable-http --allow-root ~/SageMaker --host 127.0.0.1 --port 8080 > out.txt
# Out:
# 2025-10-08 20:00:12,798 - INFO - [root] - Logging initialized. Level: INFO. Log file: /home/ec2-user/.cursor_notebook_mcp/server.log
# 2025-10-08 20:00:12,799 - INFO - [cursor_notebook_mcp.server] - Notebook MCP Server starting (Version: 0.3.1) - via cursor_notebook_mcp.server
# 2025-10-08 20:00:12,799 - INFO - [cursor_notebook_mcp.server] - Allowed Roots: ['/home/ec2-user/SageMaker']
# 2025-10-08 20:00:12,799 - INFO - [cursor_notebook_mcp.server] - Transport Mode: streamable-http
# 2025-10-08 20:00:12,854 - INFO - [cursor_notebook_mcp.server] - Notebook tools initialized and registered.
# 2025-10-08 20:00:12,854 - INFO - [cursor_notebook_mcp.server] - Running server using FastMCP's Streamable HTTP transport...
#
#
# ╭─ FastMCP 2.0 ───────────────────��──────────────────────────────────────────╮
# │                                                                            │
# │        _ __ ___ ______           __  __  _____________    ____    ____     │
# ...
